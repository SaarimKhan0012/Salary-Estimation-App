# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\saari\OneDrive\Documents\project\employee_attrition_data.csv")

# %%
print(df)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0              0.586251                    151                      0   60132
# 1              0.261161                    221                      1   79947
# 2              0.304382                    184                      0   46958
# 3              0.480779                    242                      0   40662
# 4              0.636244                    229                      1   74307
# ..                  ...                    ...                    ...     ...
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1
#
# [1000 rows x 11 columns]

# %%
print(df.head(10))
# Out:
#    Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing        Manager                 9
# 1            1   53  Female        Sales       Engineer                10
# 2            2   59  Female    Marketing        Analyst                 8
# 3            3   42  Female  Engineering        Manager                 1
# 4            4   44  Female        Sales       Engineer                10
# 5            5   47    Male        Sales  HR Specialist                10
# 6            6   58    Male    Marketing  HR Specialist                 5
# 7            7   57  Female        Sales        Analyst                 8
# 8            8   34  Female      Finance     Accountant                 6
# 9            9   57  Female    Marketing       Engineer                 7
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
# 5            0.889018                    237                      0   97212
# 6            0.688977                    155                      1   97865
# 7            0.981679                    171                      0   50113
# 8            0.010381                    177                      1   88747
# 9            0.466782                    170                      0   43283
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          0
# 8          1
# 9          0

# %%
print(df.tail(10))
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 990          990   36  Female  Engineering     Accountant                 9
# 991          991   47    Male    Marketing        Manager                 2
# 992          992   46  Female           HR        Analyst                 8
# 993          993   47  Female           HR        Analyst                 5
# 994          994   47    Male    Marketing  HR Specialist                 2
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 990            0.558512                    182                      1   65638
# 991            0.889621                    243                      0   78726
# 992            0.955095                    176                      1   79044
# 993            0.932450                    193                      0   47301
# 994            0.992018                    186                      1   31507
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 990          1
# 991          1
# 992          1
# 993          0
# 994          0
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')

# %%
df.isna()
# Out:
#      Employee_ID    Age  Gender  Department  Job_Title  Years_at_Company  \
# 0          False  False   False       False      False             False
# 1          False  False   False       False      False             False
# 2          False  False   False       False      False             False
# 3          False  False   False       False      False             False
# 4          False  False   False       False      False             False
# ..           ...    ...     ...         ...        ...               ...
# 995        False  False   False       False      False             False
# 996        False  False   False       False      False             False
# 997        False  False   False       False      False             False
# 998        False  False   False       False      False             False
# 999        False  False   False       False      False             False
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0                 False                  False                  False   False
# 1                 False                  False                  False   False
# 2                 False                  False                  False   False
# 3                 False                  False                  False   False
# 4                 False                  False                  False   False
# ..                  ...                    ...                    ...     ...
# 995               False                  False                  False   False
# 996               False                  False                  False   False
# 997               False                  False                  False   False
# 998               False                  False                  False   False
# 999               False                  False                  False   False
#
#      Attrition
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 995      False
# 996      False
# 997      False
# 998      False
# 999      False
#
# [1000 rows x 11 columns]

# %%
print(df.head())
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns='Employee_ID',inplace=True)

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\saari\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saari\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\saari\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
df['Gender'].value_counts().plot(kind='pie')
plt.ylabel("")
plt.title("Gender Count of Employees")
plt.show()

# %%
df['Job_Title'].value_counts().plot(kind='bar')
plt.ylabel("")
plt.title("Job titles  of Employees")
plt.show()

# %%
df['Department'].value_counts().plot(kind='line')
plt.ylabel("")
plt.title("Departments")
plt.show()

# %%
df['Years_at_Company'].value_counts().plot(kind='pie')
plt.ylabel("")
plt.title("Years_at_Company")
plt.show()

# %%
df.groupby('Job_Title')['Salary'].mean().sort_values(ascending=False).plot(kind='line')
plt.title("Average Salary as Job Title")
plt.xlabel('Job title')
plt.ylabel('Average Salary')
plt.show()

# %%
df.groupby(['Department','Promotion_Last_5Years'])['Salary'].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
x=df[['Years_at_Company','Satisfaction_Level','Average_Monthly_Hours']]
y=df['Salary']

# %%
! pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\saari\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\saari\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\saari\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\saari\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\saari\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.94779063, -0.39196813,  0.5832656 ],
#        [-0.59164572,  1.28868027, -0.29471417],
#        [ 0.47678899, -0.54009659, -0.19340881],
#        ...,
#        [-1.66008044,  0.96618156,  1.08979239],
#        [-0.59164572, -1.1666326 , -1.03762013],
#        [-1.66008044, -1.47481404, -1.03762013]])

# %%
import joblib
joblib.dump(scaler,'scaler.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import joblib
# ----> 2 joblib.dump(scaler,'scaler.pkl')
#
# NameError: name 'scaler' is not defined

# %%
x_test=scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-0.83186279,  0.13812073, -0.9980373 ],
#        [ 1.61479247,  1.79258017, -1.40326307],
#        [ 0.91574811,  1.31153036, -0.82919323],
#        [ 1.61479247,  0.11527814,  0.99432273],
#        [-1.18138497, -0.16021509,  1.02809154],
#        [-0.83186279,  1.66491814,  0.89301629],
#        [-1.18138497,  1.0062326 ,  0.96055392],
#        [-0.48234061, -1.21525036,  1.02809154],
#        [ 0.91574811, -1.65286899, -0.2888922 ],
#        [-1.53090715,  1.19524311,  1.70346783],
#        [ 0.56622593, -0.34145696, -0.42396746],
#        [-0.83186279,  0.15710235, -0.89673086],
#        [-0.48234061,  1.72516386,  0.25140882],
#        [-0.83186279, -0.63996727,  1.70346783],
#        [ 0.21670375, -1.91233157,  1.19693562],
#        [ 0.21670375, -0.40251688, -0.59281153],
#        [ 0.91574811, -0.15951472,  0.82547866],
#        [-0.13281843,  0.02727201,  0.48779052],
#        [ 1.26527029,  0.52049999, -0.72788679],
#        [-0.83186279, -0.48144071, -0.08627932],
#        [-1.53090715, -0.73178158, -0.49150509],
#        [ 1.61479247,  0.58206127,  0.35271526],
#        [ 0.91574811, -0.6521414 ,  1.1631668 ],
#        [-0.13281843,  1.43212485, -0.7616556 ],
#        [-0.13281843, -1.78543727, -1.30195663],
#        [ 0.56622593, -1.31915858, -0.01874169],
#        [-0.13281843, -1.40656358,  0.58909696],
#        [-1.53090715, -0.10580076,  1.29824206],
#        [ 1.61479247, -0.61662286,  0.28517763],
#        [-0.48234061,  0.08658828, -0.49150509],
#        [ 0.56622593,  1.47486744,  1.36577969],
#        [ 0.56622593, -0.13390564,  1.19693562],
#        [-0.83186279,  0.19617904, -0.25512339],
#        [-0.48234061,  0.41373439, -0.42396746],
#        [-1.53090715,  0.5910491 ,  1.6359302 ],
#        [-0.13281843,  1.51955592,  0.55532815],
#        [-1.53090715,  0.30622913, -1.43703188],
#        [-1.53090715, -0.60762142,  0.21764001],
#        [ 0.56622593,  0.57231064,  1.50085494],
#        [-1.18138497,  0.838859  , -1.63964477],
#        [ 1.26527029, -0.24251249,  0.15010238],
#        [-0.83186279, -0.11731554, -0.79542442],
#        [-1.53090715, -1.19082392, -0.72788679],
#        [ 0.21670375, -1.27645381, -1.36949426],
#        [ 0.21670375,  0.09852742,  1.50085494],
#        [-0.48234061, -0.8629504 ,  1.33201087],
#        [ 0.91574811, -1.65323485,  0.89301629],
#        [ 1.61479247,  0.49189079, -0.89673086],
#        [ 0.91574811, -0.3307885 , -1.06557493],
#        [-0.83186279,  1.06163326, -0.79542442],
#        [-0.13281843,  0.37245723,  0.18387119],
#        [ 0.91574811, -0.24761796,  0.75794103],
#        [ 1.61479247, -0.85782211,  0.75794103],
#        [-0.13281843,  0.85206776,  0.75794103],
#        [ 1.26527029,  1.13075383,  1.46708613],
#        [ 0.91574811, -1.05399957, -0.93049967],
#        [ 0.91574811, -1.27426365, -1.4708007 ],
#        [-1.53090715,  0.88717018, -1.57210714],
#        [ 0.56622593, -0.57188075, -0.35642983],
#        [ 0.91574811, -1.37450357,  0.65663459],
#        [ 1.61479247,  1.08709076,  1.3995485 ],
#        [ 1.61479247, -0.15114523,  1.66969901],
#        [-1.53090715,  0.75199205,  1.09562917],
#        [ 1.61479247,  0.82367126,  0.48779052],
#        [-0.13281843,  0.08215551, -0.79542442],
#        [-0.48234061,  1.60100904,  0.01502712],
#        [-0.83186279,  1.35602963,  1.56839257],
#        [-1.53090715, -1.89913213,  0.52155933],
#        [-0.83186279, -0.60810672,  0.45402171],
#        [-1.53090715,  1.01111639,  0.75794103],
#        [ 1.61479247, -1.56328715,  0.42025289],
#        [ 0.91574811,  0.51846564,  0.79170985],
#        [-0.48234061,  0.85939289,  0.18387119],
#        [-1.18138497, -0.1854195 ,  1.56839257],
#        [ 0.21670375, -1.46838646, -1.09934374],
#        [-1.53090715,  1.49738796, -1.60587595],
#        [ 0.56622593,  1.62681489,  1.50085494],
#        [ 0.91574811, -1.66669928,  1.60216138],
#        [ 0.91574811, -0.20180716, -0.9980373 ],
#        [ 0.91574811, -0.73148802,  0.04879594],
#        [ 1.61479247, -0.94498546, -0.22135458],
#        [-0.48234061,  1.72856335,  0.48779052],
#        [ 1.26527029, -1.82385301, -0.05251051],
#        [ 0.21670375,  0.77194067, -1.4708007 ],
#        [ 0.56622593, -1.3677551 , -1.53833833],
#        [-0.48234061,  1.67923555,  0.45402171],
#        [ 0.21670375, -0.20176889,  0.89301629],
#        [ 1.61479247,  1.04978558,  1.23070443],
#        [-1.53090715, -1.17047255,  0.65663459],
#        [-0.48234061, -1.36532948, -1.63964477]])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
def results(predictions):
    print("Mean absolute error on model is {}".format(mean_absolute_error(y_test,predictions)))
    print("Root Mean squared error on model is {}".format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
predictionlr=lr.predict(x_test)
results(predictionlr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 predictionlr=lr.predict(x_test)
#       2 results(predictionlr)
#
# NameError: name 'lr' is not defined

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
svrmodel=SVR()

# %%
param_gridsvr={
    'C':[0.1,1,10],
    'epsilon':[0.1,0.2,0.5],
    'kernel':['linear','poly','rbf'],
    'degree':[2,3,4],
}

# %%
gridsvr=GridSearchCV(svrmodel,param_gridsvr)

# %%
gridsvr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})
